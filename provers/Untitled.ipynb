# %%
from provers import p9

# %%
# %%time
LRPoSg=[
"x<=x",
"x<=y & y<=x -> x=y",
"x<=y & y<=z -> x<=z",

"(x*y)*z=x*(y*z)",
#"x*y=y*x",
"x*x=x",

"x*y<=z <-> y <= (x\ z)",
]
m4diag(p9(LRPoSg,[],100,100,[3])[3],'* <=')
# Out:
# Number of nonisomorphic models of cardinality 2  is  3
# Number of nonisomorphic models of cardinality 3  is  14
# Fine spectrum:  [1, 3, 14]
# ['*', '<=']
# 1<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.44.0 (20200408.0750)
#  -->
# <!-- Pages: 1 -->
# <svg width="48pt" height="66pt"
#  viewBox="0.00 0.00 48.00 66.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 62)">
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-62 44,-62 44,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-50" font-family="Times,serif" font-size="10.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="19.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="19.5" y="-3" font-family="Times,serif" font-size="10.00">1</text>
# </g>
# <!-- 0&#45;&#45;1 -->
# <g id="edge1" class="edge">
# <title>0&#45;&#45;1</title>
# <path fill="none" stroke="black" d="M6.89,-47.02C9.58,-38.4 15.43,-19.57 18.11,-10.96"/>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="black" cx="34.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="34.5" y="-50" font-family="Times,serif" font-size="10.00">2</text>
# </g>
# <!-- 2&#45;&#45;1 -->
# <g id="edge2" class="edge">
# <title>2&#45;&#45;1</title>
# <path fill="none" stroke="black" d="M33.01,-47.02C30.13,-38.4 23.86,-19.57 20.99,-10.96"/>
# </g>
# </g>
# </svg>
# &nbsp; &nbsp; &nbsp; <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.44.0 (20200408.0750)
#  -->
# <!-- Pages: 1 -->
# <svg width="19pt" height="113pt"
#  viewBox="0.00 0.00 19.00 113.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 109)">
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-109 15,-109 15,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-3" font-family="Times,serif" font-size="10.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-50" font-family="Times,serif" font-size="10.00">1</text>
# </g>
# <!-- 1&#45;&#45;0 -->
# <g id="edge1" class="edge">
# <title>1&#45;&#45;0</title>
# <path fill="none" stroke="black" d="M5.5,-46.68C5.5,-37.98 5.5,-19.73 5.5,-11.15"/>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-99.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-97" font-family="Times,serif" font-size="10.00">2</text>
# </g>
# <!-- 2&#45;&#45;1 -->
# <g id="edge2" class="edge">
# <title>2&#45;&#45;1</title>
# <path fill="none" stroke="black" d="M5.5,-93.68C5.5,-84.98 5.5,-66.73 5.5,-58.15"/>
# </g>
# </g>
# </svg>
# &nbsp; &nbsp; &nbsp;  &nbsp; 2<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.44.0 (20200408.0750)
#  -->
# <!-- Pages: 1 -->
# <svg width="48pt" height="66pt"
#  viewBox="0.00 0.00 48.00 66.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 62)">
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-62 44,-62 44,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-50" font-family="Times,serif" font-size="10.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-3" font-family="Times,serif" font-size="10.00">1</text>
# </g>
# <!-- 0&#45;&#45;1 -->
# <g id="edge1" class="edge">
# <title>0&#45;&#45;1</title>
# <path fill="none" stroke="black" d="M5.5,-46.68C5.5,-37.98 5.5,-19.73 5.5,-11.15"/>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="black" cx="34.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="34.5" y="-50" font-family="Times,serif" font-size="10.00">2</text>
# </g>
# </g>
# </svg>
# &nbsp; &nbsp; &nbsp; <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.44.0 (20200408.0750)
#  -->
# <!-- Pages: 1 -->
# <svg width="19pt" height="113pt"
#  viewBox="0.00 0.00 19.00 113.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 109)">
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-109 15,-109 15,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-3" font-family="Times,serif" font-size="10.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-50" font-family="Times,serif" font-size="10.00">1</text>
# </g>
# <!-- 1&#45;&#45;0 -->
# <g id="edge1" class="edge">
# <title>1&#45;&#45;0</title>
# <path fill="none" stroke="black" d="M5.5,-46.68C5.5,-37.98 5.5,-19.73 5.5,-11.15"/>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-99.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-97" font-family="Times,serif" font-size="10.00">2</text>
# </g>
# <!-- 2&#45;&#45;1 -->
# <g id="edge2" class="edge">
# <title>2&#45;&#45;1</title>
# <path fill="none" stroke="black" d="M5.5,-93.68C5.5,-84.98 5.5,-66.73 5.5,-58.15"/>
# </g>
# </g>
# </svg>
# &nbsp; &nbsp; &nbsp;  &nbsp; 3<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.44.0 (20200408.0750)
#  -->
# <!-- Pages: 1 -->
# <svg width="19pt" height="113pt"
#  viewBox="0.00 0.00 19.00 113.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 109)">
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-109 15,-109 15,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-50" font-family="Times,serif" font-size="10.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-3" font-family="Times,serif" font-size="10.00">1</text>
# </g>
# <!-- 0&#45;&#45;1 -->
# <g id="edge1" class="edge">
# <title>0&#45;&#45;1</title>
# <path fill="none" stroke="black" d="M5.5,-46.68C5.5,-37.98 5.5,-19.73 5.5,-11.15"/>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-99.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-97" font-family="Times,serif" font-size="10.00">2</text>
# </g>
# <!-- 2&#45;&#45;0 -->
# <g id="edge2" class="edge">
# <title>2&#45;&#45;0</title>
# <path fill="none" stroke="black" d="M5.5,-93.68C5.5,-84.98 5.5,-66.73 5.5,-58.15"/>
# </g>
# </g>
# </svg>
# &nbsp; &nbsp; &nbsp; <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//
# CPU times: user 41.1 ms, sys: 62.4 ms, total: 103 ms
# Wall time: 5.18 s

# %%
import networkx as nx
from graphviz import Graph
from IPython.display import display_html
def hasse_diagram(op,rel,dual):
    A = range(len(op))
    G = nx.DiGraph()
    if rel:
        G.add_edges_from([(x,y) for x in A for y in A if (op[y][x] if dual else op[x][y]) and x!=y])
    else: 
        G.add_edges_from([(x,y) for x in A for y in A if op[x][y]==(y if dual else x) and x!=y])
    try:
        G = nx.algorithms.dag.transitive_reduction(G)
    except:
        pass
    P = Graph()
    P.attr('node', shape='circle', width='.15', height='.15', fixedsize='true', fontsize='10')
    for x in A: P.node(str(x))
    P.edges([(str(x[0]),str(x[1])) for x in G.edges])
    return P

def m4diag(li,symbols="<= v"):
    i = 0
    sy = symbols.split(" ")
    print(sy)
    st = ""
    for x in li:
        i+=1
        st+=str(i)
        for s in sy:
            t = s[:-1] if s[-1]=='d' else s
            if t in x.operations.keys():
                st+=hasse_diagram(x.operations[t],False,s[-1]=='d')._repr_svg_()+"&nbsp; &nbsp; &nbsp; "
            elif t in x.relations.keys():
                st+=hasse_diagram(x.relations[t], True, s[-1]=='d')._repr_svg_()+"&nbsp; &nbsp; &nbsp; "
        st+=" &nbsp; "
    display_html(st,raw=True)

# %%
a[3][0].relations["<="]
a[3][0].operations["*"]
# Out:
# [[0, 0, 2], [0, 1, 2], [2, 2, 2]]

# %%
# %%time
LRPoSg=[
"x<=x",
"x<=y & y<=x -> x=y",
"x<=y & y<=z -> x<=z",

"(x*y)*z=x*(y*z)",
#"x*y=y*x",
"x*x=x",

"x*y<=z <-> y <= (x\ z)",
]
p9latex(p9(LRPoSg,["(x\ x)\(x\ x) <= x\ x"],0,100))
# Out:
# $\displaystyle 1\quad x \le  y \ \&\  y \le  x\implies x = y \quad []$
# $\displaystyle 2\quad x \le  y \ \&\  y \le  z\implies x \le  z \quad []$
# $\displaystyle 3\quad xy \le  z\iff y \le  x \backslash z \quad []$
# $\displaystyle 4\quad (x \backslash x) \backslash (x \backslash x) \le  x \backslash x  \quad(goal)\quad []$
# $\displaystyle 5\quad x \le  x\quad []$
# $\displaystyle 6\quad -(x \le  y) \quad\mbox{or}\quad -(y \le  x) \quad\mbox{or}\quad y = x\quad [1]$
# $\displaystyle 7\quad -(x \le  y) \quad\mbox{or}\quad -(y \le  z) \quad\mbox{or}\quad x \le  z\quad [2]$
# $\displaystyle 8\quad xyz = x(yz)\quad []$
# $\displaystyle 9\quad xx = x\quad []$
# $\displaystyle 10\quad -(xy \le  z) \quad\mbox{or}\quad y \le  x \backslash z\quad [3]$
# $\displaystyle 11\quad xy \le  z \quad\mbox{or}\quad -(y \le  x \backslash z)\quad [3]$
# $\displaystyle 12\quad -((c_1 \backslash c_1) \backslash (c_1 \backslash c_1) \le  c_1 \backslash c_1)\quad [4]$
# $\displaystyle 13\quad x \le  y \backslash yx\quad [10, 5]$
# $\displaystyle 14\quad x(x \backslash y) \le  y\quad [11, 5]$
# $\displaystyle 15\quad -(c_1((c_1 \backslash c_1) \backslash (c_1 \backslash c_1)) \le  c_1)\quad [10, 12]$
# $\displaystyle 16\quad x \le  x \backslash x\quad [9, 13]$
# $\displaystyle 17\quad -(x \backslash x \le  y) \quad\mbox{or}\quad x \le  y\quad [7, 16]$
# $\displaystyle 18\quad x \le  y \backslash y(x \backslash x)\quad [17, 13]$
# $\displaystyle 19\quad x(y(y \backslash (x \backslash z))) \le  z\quad [11, 14]$
# $\displaystyle 20\quad xy \le  x(y \backslash y)\quad [11, 18]$
# $\displaystyle 21\quad x \le  x(x \backslash x)\quad [9, 20]$
# $\displaystyle 22\quad -(x \le  y(y \backslash x)) \quad\mbox{or}\quad x = y(y \backslash x)\quad [6, 14]$
# $\displaystyle 23\quad x = x(x \backslash x)\quad [22, 21]$
# $\displaystyle 24\quad x(x \backslash x) = x\quad [23]$
# $\displaystyle 25\quad xy = x((x \backslash x)y)\quad [24, 8]$
# $\displaystyle 26\quad x((x \backslash x)y) = xy\quad [25]$
# $\displaystyle 27\quad x((x \backslash x) \backslash (x \backslash y)) \le  y\quad [26, 19]$
# $\displaystyle 28\quad F\quad [27, 15]$
# CPU times: user 45.2 ms, sys: 24.7 ms, total: 70 ms
# Wall time: 190 ms

# %%
def p9latex(pf, latex=False):
    from IPython.display import display, Math
    import re
    #for li in pf[0].proof:
    la = [str(li[0])+"\\quad "+re.sub(r"c(\d)",r"c_\1",li[1]).\
                replace(" * ","").replace("<=","\le ").replace("!=","\\ne ").\
                replace("\\ ","\\backslash ").replace(" <->","\iff").\
                replace(" ->","\\implies").replace("exists","\exists").\
                replace("# label(non_clause)","").replace("# label(goal)","\quad(goal)").\
                replace("&","\ \&\ ").replace("|","\quad\mbox{or}\quad").replace("$F","F")\
                +"\\quad "+str(li[2]) for li in pf[0].proof]
    if latex: return "$"+"$\n\n$".join(la)+"$"
    else:
        for st in la: display(Math(st))
print(p9latex(a))
# Out:
# $\displaystyle 1\quad x \le  y \ \&\  y \le  x\implies x = y \quad []$
# $\displaystyle 2\quad x \le  y \ \&\  y \le  z\implies x \le  z \quad []$
# $\displaystyle 3\quad xy \le  z\iff y \le  x \backslash z \quad []$
# $\displaystyle 4\quad (x \backslash x) \backslash (x \backslash x) \le  x \backslash x  \quad(goal)\quad []$
# $\displaystyle 5\quad x \le  x\quad []$
# $\displaystyle 6\quad -(x \le  y) \quad\mbox{or}\quad -(y \le  x) \quad\mbox{or}\quad y = x\quad [1]$
# $\displaystyle 7\quad -(x \le  y) \quad\mbox{or}\quad -(y \le  z) \quad\mbox{or}\quad x \le  z\quad [2]$
# $\displaystyle 8\quad xyz = x(yz)\quad []$
# $\displaystyle 9\quad xx = x\quad []$
# $\displaystyle 10\quad -(xy \le  z) \quad\mbox{or}\quad y \le  x \backslash z\quad [3]$
# $\displaystyle 11\quad xy \le  z \quad\mbox{or}\quad -(y \le  x \backslash z)\quad [3]$
# $\displaystyle 12\quad -((c_1 \backslash c_1) \backslash (c_1 \backslash c_1) \le  c_1 \backslash c_1)\quad [4]$
# $\displaystyle 13\quad x \le  y \backslash yx\quad [10, 5]$
# $\displaystyle 14\quad x(x \backslash y) \le  y\quad [11, 5]$
# $\displaystyle 15\quad -(c_1((c_1 \backslash c_1) \backslash (c_1 \backslash c_1)) \le  c_1)\quad [10, 12]$
# $\displaystyle 16\quad x \le  x \backslash x\quad [9, 13]$
# $\displaystyle 17\quad -(x \backslash x \le  y) \quad\mbox{or}\quad x \le  y\quad [7, 16]$
# $\displaystyle 18\quad x \le  y \backslash y(x \backslash x)\quad [17, 13]$
# $\displaystyle 19\quad x(y(y \backslash (x \backslash z))) \le  z\quad [11, 14]$
# $\displaystyle 20\quad xy \le  x(y \backslash y)\quad [11, 18]$
# $\displaystyle 21\quad x \le  x(x \backslash x)\quad [9, 20]$
# $\displaystyle 22\quad -(x \le  y(y \backslash x)) \quad\mbox{or}\quad x = y(y \backslash x)\quad [6, 14]$
# $\displaystyle 23\quad x = x(x \backslash x)\quad [22, 21]$
# $\displaystyle 24\quad x(x \backslash x) = x\quad [23]$
# $\displaystyle 25\quad xy = x((x \backslash x)y)\quad [24, 8]$
# $\displaystyle 26\quad x((x \backslash x)y) = xy\quad [25]$
# $\displaystyle 27\quad x((x \backslash x) \backslash (x \backslash y)) \le  y\quad [26, 19]$
# $\displaystyle 28\quad F\quad [27, 15]$
# None

# %%
b.proof
# Out:
# [[1, 'x <= y & y <= x -> x = y # label(non_clause)', []],
#  [2, 'x <= y & y <= z -> x <= z # label(non_clause)', []],
#  [3, 'x * y <= z <-> y <= x \\ z # label(non_clause)', []],
#  [4, '(x \\ x) \\ (x \\ x) <= x \\ x # label(non_clause) # label(goal)', []],
#  [5, 'x <= x', []],
#  [6, '-(x <= y) | -(y <= x) | y = x', [1]],
#  [7, '-(x <= y) | -(y <= z) | x <= z', [2]],
#  [8, 'x * y * z = x * (y * z)', []],
#  [9, 'x * x = x', []],
#  [10, '-(x * y <= z) | y <= x \\ z', [3]],
#  [11, 'x * y <= z | -(y <= x \\ z)', [3]],
#  [12, '-((c1 \\ c1) \\ (c1 \\ c1) <= c1 \\ c1)', [4]],
#  [13, 'x <= y \\ y * x', [10, 5]],
#  [14, 'x * (x \\ y) <= y', [11, 5]],
#  [15, '-(c1 * ((c1 \\ c1) \\ (c1 \\ c1)) <= c1)', [10, 12]],
#  [16, 'x <= x \\ x', [9, 13]],
#  [17, '-(x \\ x <= y) | x <= y', [7, 16]],
#  [18, 'x <= y \\ y * (x \\ x)', [17, 13]],
#  [19, 'x * (y * (y \\ (x \\ z))) <= z', [11, 14]],
#  [20, 'x * y <= x * (y \\ y)', [11, 18]],
#  [21, 'x <= x * (x \\ x)', [9, 20]],
#  [22, '-(x <= y * (y \\ x)) | x = y * (y \\ x)', [6, 14]],
#  [23, 'x = x * (x \\ x)', [22, 21]],
#  [24, 'x * (x \\ x) = x', [23]],
#  [25, 'x * y = x * ((x \\ x) * y)', [24, 8]],
#  [26, 'x * ((x \\ x) * y) = x * y', [25]],
#  [27, 'x * ((x \\ x) \\ (x \\ y)) <= y', [26, 19]],
#  [28, '$F', [27, 15]]]
